# %%
from sklearn.cluster import AgglomerativeClustering
import numpy as np

# %%
 X = np.array([[1, 2], [1, 4], [1, 0], [4, 2], [4, 4], [4, 0]])

# %%
clustering = AgglomerativeClustering().fit(X)

# %%
clustering
clustering.labels_

# %%
fit_predict(X[, y])
# Out:
#   File "<ipython-input-13-2b4113f7a61c>", line 1
#     fit_predict(X[, y])
#                   ^
# SyntaxError: invalid syntax
